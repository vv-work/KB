# %%
import cv2

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Reading image

# %%
img=cv2.imread('watch.jpg',1)
#IMREAD_COLOR = 1
#IMREAD_UNCHANGED = -1
#IMREAD_GRAYSCALE = 0

# %% [markdown]
# ## showing image with Mat Plot

# %%
plt.imshow(img,cmap='gray', interpolation='bicubic')
plt.plot([50,100],[80,150])
plt.show()

# %%
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
