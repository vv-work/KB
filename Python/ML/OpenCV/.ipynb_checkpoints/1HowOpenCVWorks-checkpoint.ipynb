# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('‪watch1.jpg',1)
plt.imshow(img,cmap='gray', interpolation='bicubic')
plt.plot([50,100],[80,150])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-287ffc69a469> in <module>
#       1 img = cv2.imread('‪watch1.jpg',1)
# ----> 2 plt.imshow(img,cmap='gray', interpolation='bicubic')
#       3 plt.plot([50,100],[80,150])
#       4 plt.show()
#
# b:\myprograms\python39\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2901         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2902         data=None, **kwargs):
# -> 2903     __ret = gca().imshow(
#    2904         X, cmap=cmap, norm=norm, aspect=aspect,
#    2905         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# b:\myprograms\python39\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...
