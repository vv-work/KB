# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img=cv2.imread('watch.jpg',1)
img_gray=cv2.imread('watch.jpg',0)
#IMREAD_COLOR = 1
#IMREAD_UNCHANGED = -1
#IMREAD_GRAYSCALE = 0
#cv2.imshow('image',img)
#cv2.imshow('gray',img_gray)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
img=cv2.imread('image.jpg',1)

g,b,r = cv2.split(img)
gbr_img = cv2.merge((g,b,r))
rbr_img = cv2.merge((r,b,r))

cv2.imshow('Original', img)
cv2.imshow('GRB', gbr_img)
cv2.imshow('RBR', rbr_img)
cv2.waitKey()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-0b29dcc6e59c> in <module>
# ----> 1 img=cv2.imread('image.jpg',1)
#       2
#       3 g,b,r = cv2.split(img)
#       4 gbr_img = cv2.merge((g,b,r))
#       5 rbr_img = cv2.merge((r,b,r))
#
# NameError: name 'cv2' is not defined

# %% [markdown]
# ## We will scale iamge now
# We will apply reciper form cook book

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt



Scale = 0.5

img = cv2.imread('InputImage2.jpg',0)

#img = cv2.imread('InputImage2.jpg',0)
crop = 400

img =  img[crop:1024-crop, crop:1024-crop]
img2 = img.copy()
template = cv2.imread('Template.png',0)
template = cv2.resize(template,None,fx=Scale, fy=Scale, interpolation = cv2.INTER_LINEAR)
w, h = template.shape[::-1]


# All the 6 methods for comparison in a list
methods = ['cv2.TM_CCOEFF', 'cv2.TM_CCOEFF_NORMED', 'cv2.TM_CCORR',
            'cv2.TM_CCORR_NORMED', 'cv2.TM_SQDIFF', 'cv2.TM_SQDIFF_NORMED']

for meth in methods:
    img = img2.copy()
    method = eval(meth)

    # Apply template Matching
    res = cv2.matchTemplate(img,template,method)
    min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(res)

    # If the method is TM_SQDIFF or TM_SQDIFF_NORMED, take minimum
    if method in [cv2.TM_SQDIFF, cv2.TM_SQDIFF_NORMED]:
        top_left = min_loc
    else:
        top_left = max_loc
    bottom_right = (top_left[0] + w, top_left[1] + h)
        
    cv2.rectangle(img,top_left, bottom_right, 255, 2) 

    
    plt.subplot(121),plt.imshow(res,cmap = 'gray')
    plt.title('Matching Result'), plt.xticks([]), plt.yticks([])
    plt.subplot(122),plt.imshow(img,cmap = 'gray')
    plt.title('Detected Point'), plt.xticks([]), plt.yticks([])
    plt.suptitle(meth)
    
    plt.show()

cv2.waitKey()
# Out:
# -1

# %% [markdown]
# ## Key points

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

img = cv2.imread('InputImage.jpg', cv2.IMREAD_COLOR) 
img = cv2.resize(img,None,fx=0.333, fy=0.333, interpolation = cv2.INTER_LINEAR)   

def ShowImage():
    cv2.imshow('image', img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

laplacian = cv2.Laplacian(img,cv2.CV_64F)
sobelx = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)
sobely = cv2.Sobel(img,cv2.CV_64F,0,1,ksize=5)
edges= cv2.Canny(img,200,200)



#cv2.imshow('laplacia',laplacian)
#cv2.imshow('soblx', sobelx)
#cv2.imshow('soboly',sobely)
cv2.imshow('edges',edges)

ShowImage()

# %%
# Out:
# usage: ipykernel_launcher.py [-h] [--input INPUT]
# ipykernel_launcher.py: error: unrecognized arguments: --ip=127.0.0.1 --stdin=9068 --control=9066 --hb=9065 --Session.signature_scheme="hmac-sha256" --Session.key=b"961eabb8-54b9-456b-ad31-c039a9b372b3" --shell=9067 --transport="tcp" --iopub=9069 --f=C:\Temp\tmp-12224BEYxYJFzUTZN.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
